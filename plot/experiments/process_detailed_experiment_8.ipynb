# %%
import sys; sys.path.append("/home/gonzaeve/boids/leader-follower")
from lib.file_helper import loadTrialData, loadConfigData
from lib.data_helpers import getEvalFitnesses
import numpy as np

# %%
trial_data_0 = loadTrialData(trialname="trial_0", computername="experiment_8", load_populations=False, load_evaluation_teams=True, load_training_teams=True)
trial_data_1 = loadTrialData(trialname="trial_1", computername="experiment_8", load_populations=False, load_evaluation_teams=True, load_training_teams=True)
trial_data_2 = loadTrialData(trialname="trial_2", computername="experiment_8", load_populations=False, load_evaluation_teams=True, load_training_teams=True)

trial_data_3 = loadTrialData(trialname="trial_3", computername="experiment_8", load_populations=False, load_evaluation_teams=True, load_training_teams=True)
trial_data_4 = loadTrialData(trialname="trial_4", computername="experiment_8", load_populations=False, load_evaluation_teams=True, load_training_teams=True)
trial_data_5 = loadTrialData(trialname="trial_5", computername="experiment_8", load_populations=False, load_evaluation_teams=True, load_training_teams=True)

trial_data_6 = loadTrialData(trialname="trial_6", computername="experiment_8", load_populations=False, load_evaluation_teams=True, load_training_teams=True)
trial_data_7 = loadTrialData(trialname="trial_7", computername="experiment_8", load_populations=False, load_evaluation_teams=True, load_training_teams=True)
trial_data_8 = loadTrialData(trialname="trial_8", computername="experiment_8", load_populations=False, load_evaluation_teams=True, load_training_teams=True)
# Out:
# 100%|██████████| 501/501 [00:25<00:00, 19.50it/s]
# 100%|██████████| 501/501 [00:26<00:00, 19.25it/s]
# 100%|██████████| 501/501 [00:25<00:00, 19.28it/s]
# 100%|██████████| 501/501 [00:25<00:00, 19.39it/s]
# 100%|██████████| 501/501 [00:25<00:00, 19.46it/s]
# 100%|██████████| 501/501 [00:25<00:00, 19.56it/s]
# 100%|██████████| 501/501 [00:26<00:00, 19.04it/s]
# 100%|██████████| 501/501 [00:26<00:00, 18.86it/s]
# 100%|██████████| 501/501 [00:25<00:00, 19.28it/s]

# %%
from lib.data_helpers import getEvalFitnesses

team_fitness_0, agent_fitnesses_0 = getEvalFitnesses(trial_data_0)
team_fitness_1, agent_fitnesses_1 = getEvalFitnesses(trial_data_1)
team_fitness_2, agent_fitnesses_2 = getEvalFitnesses(trial_data_2)

team_fitness_3, agent_fitnesses_3 = getEvalFitnesses(trial_data_3)
team_fitness_4, agent_fitnesses_4 = getEvalFitnesses(trial_data_4)
team_fitness_5, agent_fitnesses_5 = getEvalFitnesses(trial_data_5)

team_fitness_6, agent_fitnesses_6 = getEvalFitnesses(trial_data_6)
team_fitness_7, agent_fitnesses_7 = getEvalFitnesses(trial_data_7)
team_fitness_8, agent_fitnesses_8 = getEvalFitnesses(trial_data_8)

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

config = loadConfigData(trialname="trial_0", computername="experiment_8")
leader_colors = config["CCEA"]["config"]["BoidsEnv"]["config"]["Renderer"]["leader_colors"]
leader_colors = tuple(np.array(leader_colors)/255)

plt.plot(team_fitness_0, color="royalblue", linestyle="-")
plt.plot(team_fitness_1, color="navy", linestyle="-")
plt.plot(team_fitness_2, color="blue", linestyle="-")

plt.plot(team_fitness_3, color="darkorange", linestyle="-")
plt.plot(team_fitness_4, color="navajowhite", linestyle="-")
plt.plot(team_fitness_5, color="orange", linestyle="-")

plt.plot(team_fitness_6, color="forestgreen", linestyle="-")
plt.plot(team_fitness_7, color="limegreen", linestyle="-")
plt.plot(team_fitness_8, color="darkgreen", linestyle="-")


# print(agent_fitnesses.shape)

# num_agents = agent_fitnesses.shape
# print(num_agents)

# for ind, agent_fitness in enumerate(agent_fitnesses):
#     plt.plot(agent_fitness, color=tuple(leader_colors[ind%len(leader_colors)]))


# plt.xlabel("Generation")
# plt.ylabel("Fitness Score")
# plt.ylim([0.0,1.01])
# plt.title("Final Evaluation Teams")
# legend = ["Team Performance"]
# # for i in range(len(agent_fitnesses)):
# #     legend.append("Agent "+str(i+1))
# plt.legend(legend)
# plt.show()
# Out:
# (501, 1, 25)

# %%
trial_data[0]["evaluation_team"]["agent_fitnesses"]
